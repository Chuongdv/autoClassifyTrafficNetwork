# %%
import pandas as pd
import random

# %%
dataframe = pd.read_csv('./data/trace2/trace2.csv', encoding='utf-8', header=0, sep=',', index_col=0)
# Out:
# /home/chuongdv/anaconda3/lib/python3.7/site-packages/numpy/lib/arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2078182 entries, 0 to 2078181
# Data columns (total 57 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   Source_IP                    object
#  1   Source_Port                  int64
#  2   Destination_IP               object
#  3   Destination_Port             int64
#  4   Protocol                     int64
#  5   Flow_Duration                int64
#  6   Total_Fwd_Packets            int64
#  7   Total_Backward_Packets       int64
#  8   Total_Length_of_Fwd_Packets  int64
#  9   Total_Length_of_Bwd_Packets  float64
#  10  Fwd_Packet_Length_Max        int64
#  11  Fwd_Packet_Length_Min        int64
#  12  Fwd_Packet_Length_Mean       float64
#  13  Fwd_Packet_Length_Std        float64
#  14  Bwd_Packet_Length_Max        int64
#  15  Bwd_Packet_Length_Min        int64
#  16  Bwd_Packet_Length_Mean       float64
#  17  Bwd_Packet_Length_Std        float64
#  18  Flow_Bytes_s                 float64
#  19  Flow_Packets_s               float64
#  20  Flow_IAT_Mean                float64
#  21  Flow_IAT_Std                 float64
#  22  Flow_IAT_Max                 float64
#  23  Flow_IAT_Min                 int64
#  24  Fwd_IAT_Total                float64
#  25  Fwd_IAT_Mean                 float64
#  26  Fwd_IAT_Std                  float64
#  27  Fwd_IAT_Max                  float64
#  28  Fwd_IAT_Min                  float64
#  29  Bwd_IAT_Total                float64
#  30  Bwd_IAT_Mean                 float64
#  31  Bwd_IAT_Std                  float64
#  32  Bwd_IAT_Max                  float64
#  33  Bwd_IAT_Min                  float64
#  34  Fwd_Header_Length            int64
#  35  Bwd_Header_Length            int64
#  36  Fwd_Packets_s                float64
#  37  Bwd_Packets_s                float64
#  38  Min_Packet_Length            int64
#  39  Max_Packet_Length            int64
#  40  Packet_Length_Mean           float64
#  41  Packet_Length_Std            float64
#  42  Packet_Length_Variance       float64
#  43  Down_Up_Ratio                int64
#  44  Average_Packet_Size          float64
#  45  Avg_Fwd_Segment_Size         float64
#  46  Avg_Bwd_Segment_Size         float64
#  47  Fwd_Header_Length_1          int64
#  48  Subflow_Fwd_Packets          int64
#  49  Subflow_Fwd_Bytes            int64
#  50  Subflow_Bwd_Packets          int64
#  51  Subflow_Bwd_Bytes            int64
#  52  Init_Win_bytes_forward       int64
#  53  Init_Win_bytes_backward      int64
#  54  act_data_pkt_fwd             int64
#  55  min_seg_size_forward         int64
#  56  ProtocolName                 object
# dtypes: float64(28), int64(26), object(3)
# memory usage: 919.6+ MB

# %%
dataframe.head(5)
# Out:
#         Source_IP  Source_Port  Destination_IP  Destination_Port  Protocol  \
# 0     172.19.1.46        52422      10.200.7.7              3128         6
# 1   192.168.10.47        51848      10.200.7.6              3128         6
# 2   68.67.178.197          443    10.200.7.217             57300         6
# 3      10.200.7.4         3128  192.168.180.51             57740         6
# 4  212.124.124.94          443    10.200.7.194             44447         6
#
#    Flow_Duration  Total_Fwd_Packets  Total_Backward_Packets  \
# 0          45523                 22                      55
# 1          11002                  3                      12
# 2         108503                 10                       6
# 3         205118                 32                       4
# 4         202096                  4                       6
#
#    Total_Length_of_Fwd_Packets  Total_Length_of_Bwd_Packets  ...  \
# 0                          132                     110414.0  ...
# 1                          232                       3664.0  ...
# 2                         6904                       1302.0  ...
# 3                         6494                       3118.0  ...
# 4                          174                       3130.0  ...
#
#    Fwd_Header_Length_1  Subflow_Fwd_Packets  Subflow_Fwd_Bytes  \
# 0                  440                   22                132
# 1                   72                    3                232
# 2                  320                   10               6904
# 3                  640                   32               6494
# 4                   92                    4                174
#
#    Subflow_Bwd_Packets  Subflow_Bwd_Bytes  Init_Win_bytes_forward  \
# 0                   55             110414                     256
# 1                   12               3664                    8192
# 2                    6               1302                      60
# 3                    4               3118                     245
# 4                    6               3130                   14600
#
#    Init_Win_bytes_backward  act_data_pkt_fwd  min_seg_size_forward  \
# 0                      490                21                    20
# 1                      245                 2                    20
# 2                     1000                 7                    32
# 3                      255                31                    20
# 4                      245                 3                    20
#
#    ProtocolName
# 0    HTTP_PROXY
# 1  HTTP_CONNECT
# 2           SSL
# 3    HTTP_PROXY
# 4           SSL
#
# [5 rows x 57 columns]

# %%
dataframe.drop(['Source_IP', 'Source_Port', 'Destination_IP', 'Destination_Port', 'Protocol'], axis = 1, inplace = True)

# %%
dataframe.head(5)
# Out:
#    Flow_Duration  Total_Fwd_Packets  Total_Backward_Packets  \
# 0          45523                 22                      55
# 1          11002                  3                      12
# 2         108503                 10                       6
# 3         205118                 32                       4
# 4         202096                  4                       6
#
#    Total_Length_of_Fwd_Packets  Total_Length_of_Bwd_Packets  \
# 0                          132                     110414.0
# 1                          232                       3664.0
# 2                         6904                       1302.0
# 3                         6494                       3118.0
# 4                          174                       3130.0
#
#    Fwd_Packet_Length_Max  Fwd_Packet_Length_Min  Fwd_Packet_Length_Mean  \
# 0                      6                      6                6.000000
# 1                    226                      0               77.333333
# 2                   1448                      0              690.400000
# 3                   1460                      6              202.937500
# 4                    137                      0               43.500000
#
#    Fwd_Packet_Length_Std  Bwd_Packet_Length_Max  ...  Fwd_Header_Length_1  \
# 0               0.000000                   4380  ...                  440
# 1             128.784057                   3628  ...                   72
# 2             660.894209                   1302  ...                  320
# 3             464.035311                   1460  ...                  640
# 4              63.762580                   1460  ...                   92
#
#    Subflow_Fwd_Packets  Subflow_Fwd_Bytes  Subflow_Bwd_Packets  \
# 0                   22                132                   55
# 1                    3                232                   12
# 2                   10               6904                    6
# 3                   32               6494                    4
# 4                    4                174                    6
#
#    Subflow_Bwd_Bytes  Init_Win_bytes_forward  Init_Win_bytes_backward  \
# 0             110414                     256                      490
# 1               3664                    8192                      245
# 2               1302                      60                     1000
# 3               3118                     245                      255
# 4               3130                   14600                      245
#
#    act_data_pkt_fwd  min_seg_size_forward  ProtocolName
# 0                21                    20    HTTP_PROXY
# 1                 2                    20  HTTP_CONNECT
# 2                 7                    32           SSL
# 3                31                    20    HTTP_PROXY
# 4                 3                    20           SSL
#
# [5 rows x 52 columns]

# %%
label = dataframe['ProtocolName']

# %%
dataframe.drop(['ProtocolName'], axis = 1, inplace = True)

# %%
dataframe=((dataframe-dataframe.min())/(dataframe.max()-dataframe.min()))

# %%
dataframe.head(5)
# Out:
#    Flow_Duration  Total_Fwd_Packets  Total_Backward_Packets  \
# 0       0.000379           0.000044                0.000101
# 1       0.000092           0.000002                0.000022
# 2       0.000904           0.000018                0.000011
# 3       0.001709           0.000066                0.000007
# 4       0.001684           0.000004                0.000011
#
#    Total_Length_of_Fwd_Packets  Total_Length_of_Bwd_Packets  \
# 0                 1.946835e-07                 8.204365e-05
# 1                 3.421710e-07                 2.722553e-06
# 2                 1.018254e-05                 9.674573e-07
# 3                 9.577838e-06                 2.316845e-06
# 4                 2.566282e-07                 2.325761e-06
#
#    Fwd_Packet_Length_Max  Fwd_Packet_Length_Min  Fwd_Packet_Length_Mean  \
# 0               0.000183               0.002072                0.000905
# 1               0.006884               0.000000                0.011670
# 2               0.044103               0.000000                0.104188
# 3               0.044469               0.002072                0.030625
# 4               0.004173               0.000000                0.006565
#
#    Fwd_Packet_Length_Std  Bwd_Packet_Length_Max  ...  Avg_Bwd_Segment_Size  \
# 0               0.000000               0.116341  ...              0.246407
# 1               0.020687               0.096366  ...              0.037477
# 2               0.106159               0.034584  ...              0.026635
# 3               0.074538               0.038780  ...              0.095677
# 4               0.010242               0.038780  ...              0.064030
#
#    Fwd_Header_Length_1  Subflow_Fwd_Packets  Subflow_Fwd_Bytes  \
# 0             0.000026             0.000044       1.946835e-07
# 1             0.000002             0.000002       3.421710e-07
# 2             0.000018             0.000018       1.018254e-05
# 3             0.000039             0.000066       9.577838e-06
# 4             0.000003             0.000004       2.566282e-07
#
#    Subflow_Bwd_Packets  Subflow_Bwd_Bytes  Init_Win_bytes_forward  \
# 0             0.000101       8.204365e-05                0.003922
# 1             0.000022       2.722553e-06                0.125015
# 2             0.000011       9.674573e-07                0.000931
# 3             0.000007       2.316845e-06                0.003754
# 4             0.000011       2.325761e-06                0.222794
#
#    Init_Win_bytes_backward  act_data_pkt_fwd  min_seg_size_forward
# 0                 0.007492          0.000064              0.466667
# 1                 0.003754          0.000006              0.466667
# 2                 0.015274          0.000021              0.733333
# 3                 0.003906          0.000094              0.466667
# 4                 0.003754          0.000009              0.466667
#
# [5 rows x 51 columns]

# %%
dataframe['ProtocolName'] = label

# %%
dataframe.head(5)
# Out:
#    Flow_Duration  Total_Fwd_Packets  Total_Backward_Packets  \
# 0       0.000379           0.000044                0.000101
# 1       0.000092           0.000002                0.000022
# 2       0.000904           0.000018                0.000011
# 3       0.001709           0.000066                0.000007
# 4       0.001684           0.000004                0.000011
#
#    Total_Length_of_Fwd_Packets  Total_Length_of_Bwd_Packets  \
# 0                 1.946835e-07                 8.204365e-05
# 1                 3.421710e-07                 2.722553e-06
# 2                 1.018254e-05                 9.674573e-07
# 3                 9.577838e-06                 2.316845e-06
# 4                 2.566282e-07                 2.325761e-06
#
#    Fwd_Packet_Length_Max  Fwd_Packet_Length_Min  Fwd_Packet_Length_Mean  \
# 0               0.000183               0.002072                0.000905
# 1               0.006884               0.000000                0.011670
# 2               0.044103               0.000000                0.104188
# 3               0.044469               0.002072                0.030625
# 4               0.004173               0.000000                0.006565
#
#    Fwd_Packet_Length_Std  Bwd_Packet_Length_Max  ...  Fwd_Header_Length_1  \
# 0               0.000000               0.116341  ...             0.000026
# 1               0.020687               0.096366  ...             0.000002
# 2               0.106159               0.034584  ...             0.000018
# 3               0.074538               0.038780  ...             0.000039
# 4               0.010242               0.038780  ...             0.000003
#
#    Subflow_Fwd_Packets  Subflow_Fwd_Bytes  Subflow_Bwd_Packets  \
# 0             0.000044       1.946835e-07             0.000101
# 1             0.000002       3.421710e-07             0.000022
# 2             0.000018       1.018254e-05             0.000011
# 3             0.000066       9.577838e-06             0.000007
# 4             0.000004       2.566282e-07             0.000011
#
#    Subflow_Bwd_Bytes  Init_Win_bytes_forward  Init_Win_bytes_backward  \
# 0       8.204365e-05                0.003922                 0.007492
# 1       2.722553e-06                0.125015                 0.003754
# 2       9.674573e-07                0.000931                 0.015274
# 3       2.316845e-06                0.003754                 0.003906
# 4       2.325761e-06                0.222794                 0.003754
#
#    act_data_pkt_fwd  min_seg_size_forward  ProtocolName
# 0          0.000064              0.466667    HTTP_PROXY
# 1          0.000006              0.466667  HTTP_CONNECT
# 2          0.000021              0.733333           SSL
# 3          0.000094              0.466667    HTTP_PROXY
# 4          0.000009              0.466667           SSL
#
# [5 rows x 52 columns]

# %%
dataframe.to_csv('./data/trace2/normalizetrace2.csv', index = True)

# %%
dataframe.max()
