# %%
# Render our plots inline
# %matplotlib inline
 
import pandas as pd
import matplotlib.pyplot as plt
import random

# %%
chunks = pd.read_csv('./data/trace2/ip-network-traffic-flows-labeled-with-87-apps/Dataset-Unicauca-Version2-87Atts.csv', encoding='utf-8', header=0, sep=',', chunksize=100000)

# %%
chunk_list = []
for chunk in chunks:
    chunk.drop(['Flow.ID', 'Timestamp', 'Fwd.PSH.Flags', 'Bwd.PSH.Flags', 'Fwd.URG.Flags', 'Bwd.URG.Flags', \
                'FIN.Flag.Count', 'SYN.Flag.Count', 'RST.Flag.Count', 'PSH.Flag.Count', \
                'ACK.Flag.Count', 'URG.Flag.Count', 'CWE.Flag.Count', 'ECE.Flag.Count',\
                'Fwd.Avg.Bytes.Bulk', 'Fwd.Avg.Packets.Bulk', 'Bwd.Avg.Bulk.Rate', 'Fwd.Avg.Packets.Bulk',\
                'Fwd.Avg.Bulk.Rate', 'Bwd.Avg.Bytes.Bulk', 'Bwd.Avg.Packets.Bulk','Active.Mean', 'Active.Std',\
               'Active.Max', 'Active.Min', 'Idle.Mean', 'Idle.Std', 'Idle.Max', 'Idle.Min', 'Label', 'L7Protocol'], axis = 1, inplace =True)
    chunk_list.append(chunk)
dataframe = pd.concat(chunk_list)
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3577296 entries, 0 to 3577295
# Data columns (total 57 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   Source.IP                    object
#  1   Source.Port                  int64
#  2   Destination.IP               object
#  3   Destination.Port             int64
#  4   Protocol                     int64
#  5   Flow.Duration                int64
#  6   Total.Fwd.Packets            int64
#  7   Total.Backward.Packets       int64
#  8   Total.Length.of.Fwd.Packets  int64
#  9   Total.Length.of.Bwd.Packets  float64
#  10  Fwd.Packet.Length.Max        int64
#  11  Fwd.Packet.Length.Min        int64
#  12  Fwd.Packet.Length.Mean       float64
#  13  Fwd.Packet.Length.Std        float64
#  14  Bwd.Packet.Length.Max        int64
#  15  Bwd.Packet.Length.Min        int64
#  16  Bwd.Packet.Length.Mean       float64
#  17  Bwd.Packet.Length.Std        float64
# ...

# %%
list(dataframe.columns)
dataframe.columns = ['Source_IP',
 'Source_Port',
 'Destination_IP',
 'Destination_Port',
 'Protocol',
 'Flow_Duration',
 'Total_Fwd_Packets',
 'Total_Backward_Packets',
 'Total_Length_of_Fwd_Packets',
 'Total_Length_of_Bwd_Packets',
 'Fwd_Packet_Length_Max',
 'Fwd_Packet_Length_Min',
 'Fwd_Packet_Length_Mean',
 'Fwd_Packet_Length_Std',
 'Bwd_Packet_Length_Max',
 'Bwd_Packet_Length_Min',
 'Bwd_Packet_Length_Mean',
 'Bwd_Packet_Length_Std',
 'Flow_Bytes_s',
 'Flow_Packets_s',
 'Flow_IAT_Mean',
 'Flow_IAT_Std',
 'Flow_IAT_Max',
 'Flow_IAT_Min',
 'Fwd_IAT_Total',
 'Fwd_IAT_Mean',
 'Fwd_IAT_Std',
 'Fwd_IAT_Max',
 'Fwd_IAT_Min',
 'Bwd_IAT_Total',
 'Bwd_IAT_Mean',
 'Bwd_IAT_Std',
 'Bwd_IAT_Max',
 'Bwd_IAT_Min',
 'Fwd_Header_Length',
 'Bwd_Header_Length',
 'Fwd_Packets_s',
 'Bwd_Packets_s',
 'Min_Packet_Length',
 'Max_Packet_Length',
 'Packet_Length_Mean',
 'Packet_Length_Std',
 'Packet_Length_Variance',
 'Down_Up_Ratio',
 'Average_Packet_Size',
 'Avg_Fwd_Segment_Size',
 'Avg_Bwd_Segment_Size',
 'Fwd_Header_Length_1',
 'Subflow_Fwd_Packets',
 'Subflow_Fwd_Bytes',
 'Subflow_Bwd_Packets',
 'Subflow_Bwd_Bytes',
 'Init_Win_bytes_forward',
 'Init_Win_bytes_backward',
 'act_data_pkt_fwd',
 'min_seg_size_forward',
 'ProtocolName']

# %%
dataframe.groupby(['ProtocolName']).count()
# Out:
#                 Source_IP  Source_Port  Destination_IP  Destination_Port  \
# ProtocolName
# 99TAXI                  1            1               1                 1
# AMAZON              86875        86875           86875             86875
# APPLE                7615         7615            7615              7615
# APPLE_ICLOUD         1200         1200            1200              1200
# APPLE_ITUNES         1287         1287            1287              1287
# ...                   ...          ...             ...               ...
# WHOIS_DAS              10           10              10                10
# WIKIPEDIA            2025         2025            2025              2025
# WINDOWS_UPDATE      34471        34471           34471             34471
# YAHOO               21268        21268           21268             21268
# YOUTUBE            170781       170781          170781            170781
#
#                 Protocol  Flow_Duration  Total_Fwd_Packets  \
# ProtocolName
# ...

# %%
dataframe.query('(Protocol == 6 and Total_Fwd_Packets >= 3  and Total_Backward_Packets >= 3) or (Protocol == 17 and Total_Fwd_Packets >= 2)', inplace = True)

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2078182 entries, 0 to 3577294
# Data columns (total 57 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   Source_IP                    object
#  1   Source_Port                  int64
#  2   Destination_IP               object
#  3   Destination_Port             int64
#  4   Protocol                     int64
#  5   Flow_Duration                int64
#  6   Total_Fwd_Packets            int64
#  7   Total_Backward_Packets       int64
#  8   Total_Length_of_Fwd_Packets  int64
#  9   Total_Length_of_Bwd_Packets  float64
#  10  Fwd_Packet_Length_Max        int64
#  11  Fwd_Packet_Length_Min        int64
#  12  Fwd_Packet_Length_Mean       float64
#  13  Fwd_Packet_Length_Std        float64
#  14  Bwd_Packet_Length_Max        int64
#  15  Bwd_Packet_Length_Min        int64
#  16  Bwd_Packet_Length_Mean       float64
#  17  Bwd_Packet_Length_Std        float64
# ...

# %%
dataframe.groupby(['ProtocolName']).count()
# Out:
#                 Source_IP  Source_Port  Destination_IP  Destination_Port  \
# ProtocolName
# AMAZON              61724        61724           61724             61724
# APPLE                4259         4259            4259              4259
# APPLE_ICLOUD          819          819             819               819
# APPLE_ITUNES          722          722             722               722
# BGP                     3            3               3                 3
# ...                   ...          ...             ...               ...
# WHOIS_DAS               3            3               3                 3
# WIKIPEDIA            1133         1133            1133              1133
# WINDOWS_UPDATE      25092        25092           25092             25092
# YAHOO               14088        14088           14088             14088
# YOUTUBE            117435       117435          117435            117435
#
#                 Protocol  Flow_Duration  Total_Fwd_Packets  \
# ProtocolName
# ...

# %%
dataframe.groupby(['Protocol']).count()
# Out:
#           Source_IP  Source_Port  Destination_IP  Destination_Port  \
# Protocol
# 6           2075593      2075593         2075593           2075593
# 17             2589         2589            2589              2589
#
#           Flow_Duration  Total_Fwd_Packets  Total_Backward_Packets  \
# Protocol
# 6               2075593            2075593                 2075593
# 17                 2589               2589                    2589
#
#           Total_Length_of_Fwd_Packets  Total_Length_of_Bwd_Packets  \
# Protocol
# 6                             2075593                      2075593
# 17                               2589                         2589
#
#           Fwd_Packet_Length_Max  ...  Fwd_Header_Length_1  \
# Protocol                         ...
# 6                       2075593  ...              2075593
# 17                         2589  ...                 2589
#
#           Subflow_Fwd_Packets  Subflow_Fwd_Bytes  Subflow_Bwd_Packets  \
# Protocol
# ...

# %%
dataframe.to_csv('./data/trace2/trace2.csv', index = True)
