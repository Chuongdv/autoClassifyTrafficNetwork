# %%
# Render our plots inline
# %matplotlib inline
 
import pandas as pd
import matplotlib.pyplot as plt
import random

dataframe = pd.read_csv('./data/trace1/trace1.csv', encoding="utf-8", header=0, sep=',', index_col=0)
dataframe.head(5)
# Out:
#              srcip  srcport            dstip  dstport  proto  total_fpackets  \
# 0   150.193.38.178    32133    210.149.31.11       25      6              10
# 1  150.193.125.234    62465   172.194.224.18      443      6             101
# 2  182.243.200.203    12155   150.193.15.202       80      6               6
# 3   113.80.154.130    22066  203.141.118.229       80      6               5
# 4    202.75.123.30    41648   150.193.13.137       80      6               5
#
#    total_fvolume  total_bpackets  total_bvolume  min_fpktl  ...  sflow_fbytes  \
# 0            706              11            620         40  ...           706
# 1           6840             180         241986         40  ...          6840
# 2            450               6            961         52  ...           450
# 3            328               6            687         52  ...           328
# 4            432               5            435         52  ...           432
#
# ...

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21025 entries, 0 to 1247218
# Data columns (total 45 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   srcip           21025 non-null  object
#  1   srcport         21025 non-null  int64
#  2   dstip           21025 non-null  object
#  3   dstport         21025 non-null  int64
#  4   proto           21025 non-null  int64
#  5   total_fpackets  21025 non-null  int64
#  6   total_fvolume   21025 non-null  int64
#  7   total_bpackets  21025 non-null  int64
#  8   total_bvolume   21025 non-null  int64
#  9   min_fpktl       21025 non-null  int64
#  10  mean_fpktl      21025 non-null  int64
#  11  max_fpktl       21025 non-null  int64
#  12  std_fpktl       21025 non-null  int64
#  13  min_bpktl       21025 non-null  int64
#  14  mean_bpktl      21025 non-null  int64
#  15  max_bpktl       21025 non-null  int64
#  16  std_bpktl       21025 non-null  int64
# ...

# %%
dataframe.groupby(['label']).count()
# Out:
#        srcip  srcport  dstip  dstport  proto  total_fpackets  total_fvolume  \
# label
# dns      301      301    301      301    301             301            301
# ftp        8        8      8        8      8               8              8
# http    8253     8253   8253     8253   8253            8253           8253
# https  11333    11333  11333    11333  11333           11333          11333
# imap      40       40     40       40     40              40             40
# imaps    482      482    482      482    482             482            482
# pop3      12       12     12       12     12              12             12
# pop3s     54       54     54       54     54              54             54
# smtp     197      197    197      197    197             197            197
# ssh      345      345    345      345    345             345            345
#
#        total_bpackets  total_bvolume  min_fpktl  ...  sflow_fpackets  \
# label                                            ...
# ...

# %%
dns = dataframe.query('label == "dns"')
ftp = dataframe.query('label == "ftp"')
http= dataframe.query('label == "http"')
https = dataframe.query('label == "https"')
imap = dataframe.query('label == "imap"')
imaps = dataframe.query('label == "imaps"')
pop3 = dataframe.query('label == "pop3"')
pop3s = dataframe.query('label == "pop3s"')
smtp = dataframe.query('label == "smtp"')
ssh = dataframe.query('label == "ssh"')

# %%
dnsTest = dns.sample(frac=0.2,random_state=200) 
dnsTraining = dns.drop(dnsTest.index)
dnsOptimal = dnsTraining.sample(frac=0.2,random_state=200) 

ftpTest = ftp.sample(frac=0.2,random_state=200) 
ftpTraining = ftp.drop(ftpTest.index)
ftpOptimal = ftpTraining.sample(frac=0.2,random_state=200)

httpTest = http.sample(frac=0.2,random_state=200) 
httpTraining = http.drop(httpTest.index)
httpOptimal = httpTraining.sample(frac=0.2,random_state=200)

httpsTest = https.sample(frac=0.2,random_state=200) 
httpsTraining = https.drop(httpsTest.index)
httpsOptimal = httpsTraining.sample(frac=0.2,random_state=200)

imapTest = imap.sample(frac=0.2,random_state=200) 
imapTraining = imap.drop(imapTest.index)
imapOptimal = imapTraining.sample(frac=0.2,random_state=200)

imapsTest = imaps.sample(frac=0.2,random_state=200) 
imapsTraining = imaps.drop(imapsTest.index)
imapsOptimal = imapsTraining.sample(frac=0.2,random_state=200)

pop3Test = pop3.sample(frac=0.2,random_state=200) 
pop3Training = pop3.drop(pop3Test.index)
pop3Optimal = pop3Training.sample(frac=0.2,random_state=200)

pop3sTest = pop3s.sample(frac=0.2,random_state=200) 
pop3sTraining = pop3s.drop(pop3sTest.index)
pop3sOptimal = pop3sTraining.sample(frac=0.2,random_state=200)

smtpTest = smtp.sample(frac=0.2,random_state=200) 
smtpTraining = smtp.drop(smtpTest.index)
smtpOptimal = smtpTraining.sample(frac=0.2,random_state=200)

sshTest = ssh.sample(frac=0.2,random_state=200) 
sshTraining = ssh.drop(sshTest.index)
sshOptimal = sshTraining.sample(frac=0.2,random_state=200)

# %%
setTest = dnsTest.append(ftpTest, ignore_index = True).append(httpTest, ignore_index = True).append(httpsTest, ignore_index = True)\
.append(imapTest, ignore_index = True).append(imapsTest, ignore_index = True).append(pop3Test, ignore_index = True)\
.append(pop3sTest, ignore_index = True).append(smtpTest, ignore_index = True).append(sshTest, ignore_index = True)

# %%
setTest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4205 entries, 0 to 4204
# Data columns (total 45 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   srcip           4205 non-null   object
#  1   srcport         4205 non-null   int64
#  2   dstip           4205 non-null   object
#  3   dstport         4205 non-null   int64
#  4   proto           4205 non-null   int64
#  5   total_fpackets  4205 non-null   int64
#  6   total_fvolume   4205 non-null   int64
#  7   total_bpackets  4205 non-null   int64
#  8   total_bvolume   4205 non-null   int64
#  9   min_fpktl       4205 non-null   int64
#  10  mean_fpktl      4205 non-null   int64
#  11  max_fpktl       4205 non-null   int64
#  12  std_fpktl       4205 non-null   int64
#  13  min_bpktl       4205 non-null   int64
#  14  mean_bpktl      4205 non-null   int64
#  15  max_bpktl       4205 non-null   int64
#  16  std_bpktl       4205 non-null   int64
# ...

# %%
setTrain = dnsTraining.append(ftpTraining, ignore_index = True).append(httpTraining, ignore_index = True).append(httpsTraining, ignore_index = True)\
.append(imapTraining, ignore_index = True).append(imapsTraining, ignore_index = True).append(pop3Training, ignore_index = True)\
.append(pop3sTraining, ignore_index = True).append(smtpTraining, ignore_index = True).append(sshTraining, ignore_index = True)

# %%
setTrain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16820 entries, 0 to 16819
# Data columns (total 45 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   srcip           16820 non-null  object
#  1   srcport         16820 non-null  int64
#  2   dstip           16820 non-null  object
#  3   dstport         16820 non-null  int64
#  4   proto           16820 non-null  int64
#  5   total_fpackets  16820 non-null  int64
#  6   total_fvolume   16820 non-null  int64
#  7   total_bpackets  16820 non-null  int64
#  8   total_bvolume   16820 non-null  int64
#  9   min_fpktl       16820 non-null  int64
#  10  mean_fpktl      16820 non-null  int64
#  11  max_fpktl       16820 non-null  int64
#  12  std_fpktl       16820 non-null  int64
#  13  min_bpktl       16820 non-null  int64
#  14  mean_bpktl      16820 non-null  int64
#  15  max_bpktl       16820 non-null  int64
#  16  std_bpktl       16820 non-null  int64
# ...

# %%
setOptimal = dnsOptimal.append(ftpOptimal, ignore_index = True).append(httpOptimal, ignore_index = True).append(httpsOptimal, ignore_index = True)\
.append(imapOptimal, ignore_index = True).append(imapsOptimal, ignore_index = True).append(pop3Optimal, ignore_index = True)\
.append(pop3sOptimal, ignore_index = True).append(smtpOptimal, ignore_index = True).append(sshOptimal, ignore_index = True)

# %%
setOptimal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3363 entries, 0 to 3362
# Data columns (total 45 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   srcip           3363 non-null   object
#  1   srcport         3363 non-null   int64
#  2   dstip           3363 non-null   object
#  3   dstport         3363 non-null   int64
#  4   proto           3363 non-null   int64
#  5   total_fpackets  3363 non-null   int64
#  6   total_fvolume   3363 non-null   int64
#  7   total_bpackets  3363 non-null   int64
#  8   total_bvolume   3363 non-null   int64
#  9   min_fpktl       3363 non-null   int64
#  10  mean_fpktl      3363 non-null   int64
#  11  max_fpktl       3363 non-null   int64
#  12  std_fpktl       3363 non-null   int64
#  13  min_bpktl       3363 non-null   int64
#  14  mean_bpktl      3363 non-null   int64
#  15  max_bpktl       3363 non-null   int64
#  16  std_bpktl       3363 non-null   int64
# ...

# %%
setTrain.to_csv('./data/trace1/trainingSetTrace1.csv', index = True)
setTest.to_csv('./data/trace1/testSetTrace1.csv', index = True)
setOptimal.to_csv('./data/trace1/optimalSetTrace1.csv', index = True)
