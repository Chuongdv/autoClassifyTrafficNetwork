# %%
# Render our plots inline
# %matplotlib inline
 
import pandas as pd
import matplotlib.pyplot as plt
import random

optimalFrame = pd.read_csv('./data/trace2/optimalSet.csv', encoding="utf-8", header=0, sep=',', index_col=0)
optimalFrame.head(5)
# Out:
#    Flow_Duration  Total_Fwd_Packets  Total_Backward_Packets  \
# 0       48098563                  7                       5
# 1         263712                  6                       4
# 2       59371158                  9                       6
# 3         242121                  6                       4
# 4         288467                  5                      15
#
#    Total_Length_of_Fwd_Packets  Total_Length_of_Bwd_Packets  \
# 0                         1541                       1757.0
# 1                          671                        185.0
# 2                         1026                       1116.0
# 3                          672                        185.0
# 4                          526                       1635.0
#
#    Fwd_Packet_Length_Max  Fwd_Packet_Length_Min  Fwd_Packet_Length_Mean  \
# 0                    791                      0              220.142857
# 1                    670                      0              111.833333
# ...

# %%
datarun = optimalFrame[['Fwd_Packet_Length_Mean','Fwd_Packet_Length_Std',\
                    'Bwd_Packet_Length_Std', 'Bwd_Packet_Length_Mean', 'Fwd_IAT_Mean', 'Flow_Duration', 'Total_Length_of_Fwd_Packets']]

# %%
datarun.index.name = "index"
datarun.to_csv('./data/trace2/autoclassOptimal.tsv',sep="\t", index = True, header = True)

# %%
import autoclasswrapper as wrapper
# Create object to prepare dataset.
clust = wrapper.Input()

# Load datasets from tsv files.
clust.add_input_data("./data/trace2/autoclassOptimal.tsv", "real location")

# Prepare input data:
# - create a final dataframe
# - merge datasets if multiple inputs
clust.prepare_input_data()

# Create files needed by AutoClass.
clust.create_db2_file()
clust.create_hd2_file()
clust.create_model_file()
clust.create_sparams_file(max_duration = 0)
clust.create_rparams_file()
# Out:
# 2020-04-20 23:30:51 INFO     Reading data file './data/trace2/autoclassOptimal.tsv' as 'real location' with error 0.01
# 2020-04-20 23:30:51 INFO     Detected encoding: ascii
# 2020-04-20 23:30:52 INFO     Found 332507 rows and 8 columns
# 2020-04-20 23:30:52 DEBUG    Checking column names
# 2020-04-20 23:30:52 DEBUG    Index name 'index'
# 2020-04-20 23:30:52 DEBUG    Column name 'Fwd_Packet_Length_Mean'
# 2020-04-20 23:30:52 DEBUG    Column name 'Fwd_Packet_Length_Std'
# 2020-04-20 23:30:52 DEBUG    Column name 'Bwd_Packet_Length_Std'
# 2020-04-20 23:30:52 DEBUG    Column name 'Bwd_Packet_Length_Mean'
# 2020-04-20 23:30:52 DEBUG    Column name 'Fwd_IAT_Mean'
# 2020-04-20 23:30:52 DEBUG    Column name 'Flow_Duration'
# 2020-04-20 23:30:52 DEBUG    Column name 'Total_Length_of_Fwd_Packets'
# 2020-04-20 23:30:52 INFO     Checking data format
# 2020-04-20 23:30:52 INFO     Column 'Fwd_Packet_Length_Mean'
# 2020-04-20 23:30:52 INFO     count    332507.000000
# ...

# %%
# Clean previous status file and results if a classification has already been performed.
# !rm -f autoclass-run-* *.results-bin

# Search autoclass in path.
wrapper.search_autoclass_in_path()

# Create object to run AutoClass.
run = wrapper.Run()

# Prepare run script.
run.create_run_file()

# Run AutoClass.
run.run()
# Out:
# 2020-04-20 23:31:35 INFO     AutoClass C executable found in /home/chuongdv/Documents/SourceCode/MachineLearning/autoclass-c/autoclass
# 2020-04-20 23:31:35 INFO     Writing run file
# 2020-04-20 23:31:35 INFO     AutoClass C executable found in /home/chuongdv/Documents/SourceCode/MachineLearning/autoclass-c/autoclass
# 2020-04-20 23:31:35 INFO     AutoClass C version: AUTOCLASS C (version 3.3.6unx)
# 2020-04-20 23:31:35 INFO     Running clustering...
