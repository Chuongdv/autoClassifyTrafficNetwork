# %%
import numpy as np
import pandas as pd
import os 

dataframe = pd.read_csv('/home/chuongdv/Documents/SourceCode/MachineLearning/data/trace1/resultTrace1.csv', header=0, sep=',', index_col=0)
dataframe.head(5)
# Out:
#                  srcip  srcport            dstip  dstport  proto  \
# index
# 0        150.193.9.119    36194  199.253.112.198       53      6
# 1       133.180.64.216    34049   202.252.24.239       53      6
# 2      203.141.113.140    48631    194.178.73.34       53      6
# 3      133.154.140.225    42868   202.252.24.239       53      6
# 4        150.193.9.119    44855  204.123.216.116       53      6
#
#        total_fpackets  total_fvolume  total_bpackets  total_bvolume  \
# index
# 0                   6            363               4            795
# 1                   6            350               4           1319
# 2                   6            379               4           1162
# 3                   6            367               4           1139
# 4                   6            365               4            990
#
#        min_fpktl  ...  sflow_bpackets  sflow_bbytes  fpsh_cnt  bpsh_cnt  \
# index             ...
# ...

# %%
dataframe.groupby('cluster').apply(lambda x: x['label'].value_counts().max()/ x.shape[0]).mean()
# Out:
# 0.8603863889369314
